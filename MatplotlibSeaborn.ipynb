# %%
#Explore the relationship between the number of gears a car has, and its combined MPG rating. Visualize these two dimensions using a scatter plot, lmplot, jointplot, boxplot, and swarmplot. 
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set()
df = pd.read_csv("http://media.sundog-soft.com/SelfDriving/FuelEfficiency.csv")

#Getting the total number of records in the dataframe ,, Both are avaiable in 'pandas'
data_count=len(df)  #Using the len() function
print(data_count)
     
data_count1=df.shape[0]   #Using the shape attribute
print(data_count1)

print(df)
# Out:
# 718
# 718

# %%
#scatterplot 
sns.scatterplot(x="# Gears", y="CombMPG",data=df )  #Remember to pass the data also
# Out:
# <Axes: xlabel='# Gears', ylabel='CombMPG'>

# %%
#implot  ,, The "lmplot" is a scatterplot, but with a linear regression line computed and overlaid onto the data.
sns.lmplot(x='# Gears', y="CombMPG", data=df)

# %%
#jointplot
sns.jointplot(x='# Gears', y="CombMPG", data=df)

# %%
#boxplot
sns.boxplot(x='# Gears', y="CombMPG", data=df)
# Out:
# <Axes: xlabel='# Gears', ylabel='CombMPG'>

# %%
#swarmplot
sns.swarmplot(x='# Gears', y="CombMPG", data=df)
# Out:
# <Axes: xlabel='# Gears', ylabel='CombMPG'>
